# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
salaries=pd.read_csv('ds_salaries.csv')
salaries
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
salaries.tail(5)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %%
salaries.head(5)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
salaries.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
len(salaries)
# Out:
# 3755

# %%
len(salaries.columns)
# Out:
# 11

# %%
#Data science salaries 2020 to 2023 analysis:
#Importing libs and reading data
#Data Transformation
#Exploratory Data Analysis
#Top 10 most common job titles
#Employees with their residence the same as the company location
#Top 10 company location with most employees
#Average salary over the years
#Average salary for the top 10 most common jobs

# %%
topjobs=salaries['job_title'].value_counts().sort_values(ascending=False).head(10).reset_index()
topjobs             #topjobs=salaries['job_title'].value_counts().nlargest(10).reset_index()
# Out:
#                    job_title  count
# 0              Data Engineer   1040
# 1             Data Scientist    840
# 2               Data Analyst    612
# 3  Machine Learning Engineer    289
# 4         Analytics Engineer    103
# 5             Data Architect    101
# 6         Research Scientist     82
# 7       Data Science Manager     58
# 8          Applied Scientist     58
# 9          Research Engineer     37

# %%
topjobs=pd.DataFrame(topjobs)
topjobs
# Out:
#                    job_title  count
# 0              Data Engineer   1040
# 1             Data Scientist    840
# 2               Data Analyst    612
# 3  Machine Learning Engineer    289
# 4         Analytics Engineer    103
# 5             Data Architect    101
# 6         Research Scientist     82
# 7       Data Science Manager     58
# 8          Applied Scientist     58
# 9          Research Engineer     37

# %%
plt.figure(figsize=(10,5))
s1=sns.barplot(topjobs,x='job_title',y='count',color='green')
plt.xticks(rotation=45,ha='right')
plt.title('Top Jobs In IT')
plt.tight_layout()                                    #Top 10 most common job titles
plt.show()

# %% [markdown]
# Analysis:The above plot shows the top IT jobs, Data Engineering gains more popularity and has a count of 1040 acorss different countries.

# %%
#Top 10 company location with most employees
comploc=salaries['company_location'].value_counts().sort_values(ascending=False).reset_index().head(10)
comploc
# Out:
#   company_location  count
# 0               US   3040
# 1               GB    172
# 2               CA     87
# 3               ES     77
# 4               IN     58
# 5               DE     56
# 6               FR     34
# 7               BR     15
# 8               PT     14
# 9               GR     14

# %%
comploc=pd.DataFrame(comploc)
comploc
# Out:
#   company_location  count
# 0               US   3040
# 1               GB    172
# 2               CA     87
# 3               ES     77
# 4               IN     58
# 5               DE     56
# 6               FR     34
# 7               BR     15
# 8               PT     14
# 9               GR     14

# %%
s2=sns.barplot(comploc,x='company_location',y='count',color='green')
plt.title('Top 10 location with most employees')
plt.xlabel('Location')
plt.ylabel('Employees')
plt.tight_layout()                       #Top 10 company location with most employees
plt.show()

# %%
#Average salary over the years
avgSalaries=salaries.groupby('work_year')['salary'].mean().reset_index().round()
avgSalaries
# Out:
#    work_year    salary
# 0       2020  386353.0
# 1       2021  544163.0
# 2       2022  165421.0
# 3       2023  160381.0

# %%
avgSalaries=pd.DataFrame(avgSalaries)
avgSalaries
# Out:
#    work_year    salary
# 0       2020  386353.0
# 1       2021  544163.0
# 2       2022  165421.0
# 3       2023  160381.0

# %%
s3=sns.barplot(avgSalaries,x='work_year',y='salary',color='green')
plt.xlabel('Work Year')
plt.title('Salary over the Years')
plt.tight_layout()                           #Average salary over the years
plt.show()

# %%
#Average salary for the top 10 most common jobs
salary10jobs=salaries.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False).reset_index().round().head(10)
salary10jobs
# Out:
#                             job_title  salary_in_usd
# 0              Data Science Tech Lead       375000.0
# 1                Cloud Data Architect       250000.0
# 2                           Data Lead       212500.0
# 3                 Data Analytics Lead       211254.0
# 4            Principal Data Scientist       198171.0
# 5            Director of Data Science       195141.0
# 6             Principal Data Engineer       192500.0
# 7  Machine Learning Software Engineer       192420.0
# 8                Data Science Manager       191279.0
# 9                   Applied Scientist       190264.0

# %%
salary10jobs=pd.DataFrame(salary10jobs)
salary10jobs
# Out:
#                             job_title  salary_in_usd
# 0              Data Science Tech Lead       375000.0
# 1                Cloud Data Architect       250000.0
# 2                           Data Lead       212500.0
# 3                 Data Analytics Lead       211254.0
# 4            Principal Data Scientist       198171.0
# 5            Director of Data Science       195141.0
# 6             Principal Data Engineer       192500.0
# 7  Machine Learning Software Engineer       192420.0
# 8                Data Science Manager       191279.0
# 9                   Applied Scientist       190264.0

# %%
if isinstance(salary10jobs,pd.DataFrame):
    print('True')
else:    
    print('False')
# Out:
# True

# %%
plt.figure(figsize=(10,4))
s4=sns.barplot(salary10jobs,x='job_title',y='salary_in_usd',color='red')
plt.title('Average salary for the top 10 most common jobs')
plt.tight_layout()                         #Average salary for the top 10 most common jobs
plt.xticks(rotation=45,ha='right')       #avg_salary_by_title = df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)[:10]
plt.show()

# %%
#Employees with their residence the same as the company location
ResidenceSameLocation=salaries[salaries['company_location']==salaries['employee_residence']]
ResidenceSameLocation
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
salaries['company_location'].isin(salaries['employee_residence'])   ###to check if both column values match one another
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3750    True
# 3751    True
# 3752    True
# 3753    True
# 3754    True
# Name: company_location, Length: 3755, dtype: bool

# %%
match=salaries['employee_residence']==salaries['company_location']####to check if both column values match one another
match
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3750    True
# 3751    True
# 3752    True
# 3753    True
# 3754    True
# Length: 3755, dtype: bool

# %%
#same_location= df[df['employee_residence'] == df['company_location']]
#print(same_location)
#avg_salary_by_title = df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=False)[:10]
